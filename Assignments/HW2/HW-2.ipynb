# %%
#=== COURSE REPO SETUP === #

# 1. ENTER your GitHub username (the one that owns your fork)
github_username = "dplant227"

# 2. Name of the repo (don't change unless your fork name is different)
repo_name = "STAT-7220-Applied-Experimental-Design"

# 3. Build the full repo URL for cloning
repo_url = f"https://github.com/{github_username}/{repo_name}.git"

import os

# --- Detect if we're already in a repo ---
cwd = os.getcwd()
if cwd.endswith(repo_name):
    print(f"✅ Already inside repo folder: {cwd}")
else:
    # --- If the repo folder exists, check if it's nested ---
    if os.path.exists(repo_name):
        print(f"⚠️ Found existing folder '{repo_name}'. Skipping clone to avoid nesting.")
    else:
        print(f"📥 Cloning repo from {repo_url}...")
        os.system(f"git clone {repo_url}")

    # --- Change to repo directory ---
    if os.path.exists(repo_name):
        os.chdir(repo_name)
        print(f"📂 Changed directory to: {os.getcwd()}")
    else:
        print("❌ ERROR: Repo folder not found. Please check your GitHub username.")

# --- Check if this is the instructor's repo instead of student's fork ---
# This command needs to be run from within the repository directory
remote_url = os.popen("git config --get remote.origin.url").read().strip()

if "abrown9008" in remote_url:
    print("⚠️ WARNING: You are working in the instructor's repo, not your fork!")
    print("💡 Please fork the repo to your own account and update `github_username` above.")
else:
    print(f"🔗 Connected to fork at: {remote_url}")

# Set Today's Directory #

today_dir = "Assignments/HW2"
os.chdir(today_dir)
print(f"📂 Changed directory to: {os.getcwd()}")
# Out:
# 📥 Cloning repo from https://github.com/dplant227/STAT-7220-Applied-Experimental-Design.git...
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design
# 🔗 Connected to fork at: https://github.com/dplant227/STAT-7220-Applied-Experimental-Design.git
# 📂 Changed directory to: /content/STAT-7220-Applied-Experimental-Design/Assignments/HW2

# %% [markdown]
# # Homework 2: Randomized Block and Latin Square Designs
# ## Daniel Perez Ulloa
# ### School of Data Science & Analytics
# ### Kennesaw State University
#
# **DUE: February 20, 2026**
#
# **PART 1 INSTRUCTIONS:** You are an educational researcher interested in comparing different methods for teaching data science to undergraduate students. There are three different methods you are interested in comparing: (1) Direct Instruction (traditional method); (2) Inquiry-Based Learning (teacher facilitates student problem solving); (3) Collaborative Learning (students working in small groups). To compare these methods, you decide to randomly recruit undergraduate data science students to be part of a workshop on hypothesis testing basics. Students will be randomly assigned to one of three workshops, where each workshop employs a different teaching method. At the end of the workshop, students will be given a 50-question quiz where their understanding of hypothesis testing will be assessed. Percentage scores on this quiz serve as the outcome of interest.
#
# However, it would be apparent that the prior level of knowledge a student possess about hypothesis testing may serve as a potential confounding variable that you would want to control for. Thus, the Prior Knowledge a given student has about hypothesis testing is categorized into "High" and "Low". The data from this experiment are contained in the `Data Science Teaching Method.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
# The objective of this experiment are to compare the teaching data from each type to find the best teaching method.
#
# **Question 2.** Specify the outcome variable
#
# Percentage Scores is the outcome variable.
#
# **Question 3.** Specify the independent variable and blocking factor. What are some possible lurking variables?
#
# The independent variable are the teaching methods, and the blocking factor would be the prior knowledge level. Possible lurking variables are sleep quality, amount of classes taken.
#
# **Question 4.** Briefly explain why a randomized block design would be appropriate here. Similarly, explain why a completely randomized design would not be appropriate.
#
# A randomized block design would be appropriate here because experimental units, grade, are not homogeneous with respect to a particular variable, which is Teaching method. A fully randomized design would not be appropriate because there is no interaction between the blocks and the treatment, but it might be found that way when running tests.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# Null Hypothesis: There is no difference between teaching methods.
#
# Alternative hypothesis: There is a difference between teaching methods.
#
# **Question 6.** Perform appropriate exploratory analysis, including summary statistics **and** data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# **Question 7.** Build a two-way ANOVA model. Test the assumption of normality using **both** a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
# Yes. Using the QQ plot the points do not stray from the line. Testing with Shapiro-Wilk test, the residuals were found to be normally distributed, failing to reject H0.
#
# **Question 8.** Test the assumption of homogeneity of variance using **both** a visual method and a testing method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# The visual method employed was the plot of standardized residuals vs Fitted values, showing points cattered around 0, and the heights of the lines are about the same. Using a testing method of B-P, we achieved a test statistic of 2.34, and a p-value above 0.05, failing to reject our hypothesis proving no heteroscedasticity detected.
#
# **Question 9.** Report the F-statistic and its associated p-value for the treatment effect. Which of our two hypotheses is more strongly supported? Why?
#
# The F-statistic calculated was 11.63 with its associated p-value being 0.00060, which is less than alpha. This would suggest that our data more strongly supports the alternative hypothesis.
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# Collaborative and Direct have the p-value being less than 0.05, suggesting group means differ substantially, controlling for Prior knowledge. Collaborative and Inquiry have a p-value of 0.08, which is close to alpha of 0.05, much closer then Inquiry and Direct, with a p-value of 0.12. This suggests that Collaborative teaching method produces better score.
#
# **Question 11.** Write a brief, contextual conclusion summarizing the results of your analyses, including potential limitations and future directions of this experiment.
#
# This study aimed to determine the most effective teaching method for data science students while controlling for prior knowledge. The analysis run determined that Collaborative learning method resulted in the highest quiz scores, which performed significantly better than the Direct method. This study also showed that Collaborative learning showed higher average scores than Inquiry based, but not enough to be significantly significant at the 5% level. Prior knowledge was confirmed to be a strong predictor of success which justified the use of the randomized block design. Limitations for this experiment are sample size and assessment type. A bigger sample size might reveal more differences between the teaching methods, and a different assessment type would capture broader competencies and retention. Future studies should consider a larger sample size and assess performance over different courses.
#
# **PART 2 INSTRUCTIONS**: Now suppose a university is evaluating the effectiveness of four different online learning platforms (say A, B, C, and D) on student engagement for students taking an undergraduate data science course in an online synchronous format. One section of the course is offered Monday through Thursday in the Morning, Early Afternoon, Mid-Afternoon, and Evening sections. Student engagement is measured through the total number of logins to the online learning platform for a given course section over the course of the
# semester. Below is a table describing the study design and factors:
#
#
# | Section \ Day     | Monday | Tuesday | Wednesday | Thursday |
# |-------------------|--------|---------|-----------|----------|
# | **Morning**       | A      | B       | C         | D        |
# | **Early Afternoon** | B      | C       | D         | A        |
# | **Mid-Afternoon** | C      | D       | A         | B        |
# | **Evening**       | D      | A       | B         | C        |
#
#
# Here, our main interest is in comparing engagement across the online learning platforms, but we also want to control for Day of the Week as well as Time of Day, as these could potentially be confounding variables. The data for this experiment are contained in the `Online Learning and Engagement.xlsx` file. With these data, your tasks are:
#
# **Question 1.** Briefly define the objective of this experiment
#
#   The objective of this experiment is to see which online learning platform had the most engagement.
#
# **Question 2.** Specify the outcome variable
#
#   The outcome variable is Student engagement.
#
# **Question 3.** Specify the independent variable and blocking factors. What are some other possible lurking variables?
#
#   The independent variable is the Online Learning Platform, and the blocking factors are day of the week and time of day. Other lurking variables could be
#
# **Question 4.** Briefly explain why a Latin Square Design would be appropriate here. Similarly, explain why a completely randomized design or randomized block design would not be appropriate.
#
# Latin Square design would be appropriate here because there are two blocking factors. These 2 blocking factors have equal number of levels which create a 4 x 4 Latin square. A completely randomized design would not be appropriate as it might cause false positives due to the confounding variables we are blocking for.
#
# **Question 5.** State the null and alternative hypotheses for this experiment.
#
# Null Hypothesis: There is no evidence for a difference between Online Learning Platform methods and Student engagement.
#
# Alternative Hypothesis: There is evidence for a difference between Online Learning Platform methods and Student engagement
#
# **Question 6.** Perform appropriate exploratory analysis, including summary statistics **and** data visualizations. Do the results of these analyses support the null or alternative hypothesis more strongly?
#
# The results of the Boxplot show that the Method A is currently having higher engagement, which is shown as well in the summary statistics. This would support the alternative hypothesis more strongly.
#
# **Question 7.** Build a three-way ANOVA model. Test the assumption of normality using **both** a visual method and a testing method. Do the results of the normality test(s) support the assumption of normality?
#
# Yes. Using the QQ plot the points stray equally about the line. Testing with Shapiro-Wilk test, the residuals were found to be normally distributed, failing to reject H0.
#
# **Question 8.** Test the assumption of homogeneity of variance using **both** a visual method and a testing method. Do the results of the test(s) support the assumption of homogeneity of variance?
#
# The visual method employed was the plot of standardized residuals vs Fitted values, showing points cattered around 0, and the heights of the lines are about the same. Using a testing method of B-P a p-value above 0.05, failing to reject our hypothesis proving no heteroscedasticity detected. This supports the assumption of homogeneity of variance.
#
# **Question 9.** Report the F-statistic and its associated p-value for the treatment effect. Which of our two hypotheses is more strongly supported? Why?
#
# The F-statistic is found to be 7.61 with a p value of 0.018 which is less of an alpha of 0.05. This supports the alternative hypothesis with evidence for a difference between Online Learning Platform methods and Student engagement
#
# **Question 10.** If the data more strongly support the alternative hypothesis, perform Tukey's HSD post-hoc test to determine which levels of the treatment effect are significantly different from each other. If the data more strongly support the null hypothesis, explain why a post-hoc test would not be appropriate.
#
# From the output, we see that the mean score for Method A may contain significant differences from B and C, controlling for operator and machine effects. Additionally, D had closer to significant differences from B and C as well, but the difference between A and D was not significant. Making the choice between the teaching methods, Method A would be suggested.
#
# **Question 11.** Write a brief conclusion summarizing the results of your analyses, including potential limitations and future directions of this experiment.
#
# This experiment evaluated four online learning platforms to identify which one maximized student engagement, while controlling for the d.y of the week and the time of day. The results indicate a significant difference in engagement levels across the platforms. Testing identified Platform A as the most effective as it performed significantly better than platforms B and C. Limitations of this study could be metric definition, as engagement was measured solely by login amount, which does not accurately reflect the quality of student participation. Additionallly the sections might have different instructor styles or content per each section that were not controlled. Future research could include qualitative metrics to supplement login data, such as time spent on tasks or survey data. Repeating the experiment across different disciplines would help determine the effecitveness of platforms across different subjects.

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
from statsmodels.stats.diagnostic import het_breuschpagan


#p1 Import Data#
dstm = pd.read_excel("Data Science Teaching Method.xlsx", engine = 'openpyxl')

#p1 Question 6 Exploratory Data Analysis.
print("Question 6: Exploratory Data Analysis")
print(dstm.columns.tolist())
print(dstm.describe(include="all").T)

print(dstm.info())

#specifying order

know_order = ['Low', 'High']

dstm['Prior_Knowledge'] = pd.Categorical(dstm['Prior_Knowledge'], categories=know_order, ordered =True)

#plot
sns.set_style("whitegrid")

sns.boxplot(
    data=dstm,
    x='Teaching_Method',
    y='Score',
    hue='Prior_Knowledge',
    hue_order=know_order, #order it nice
    palette = 'pastel'
)
plt.title("Effect of Teaching Method on Scores\nby Prior Knowledge",
          loc='center',
          fontsize=16)
plt.show()

#p1 Question 7 ANOVA
print("Question 7")
#fit model
dstm_mod = ols('Score ~ Teaching_Method + Prior_Knowledge', data=dstm).fit()
print(dstm_mod.summary())

#obtain anova table
dstm_table = sm.stats.anova_lm(dstm_mod, type=3)
print(dstm_table)

#Add significance column
dstm_table["significant"] = np.where(dstm_table["PR(>F)"] < 0.05, "Significant", "Not Significant")
print(dstm_table.loc[["Teaching_Method", "Prior_Knowledge"]])
#Check for Normality
dstm_residuals = dstm_mod.resid

#QQ plot

sm.qqplot(dstm_residuals, line='s')
plt.title("QQ Plot of Residuals")
plt.show()

#Shapiro Wilk test
shapiro_test = stats.shapiro(dstm_residuals)
print(shapiro_test)

#Test stat
shapiro_stat = shapiro_test.statistic

#p-value
shapiro_p = shapiro_test.pvalue

print(f"Shapiro-Wilk Test Statistic: {shapiro_stat:.4f}")
print(f"Shapiro-Wilk Test P-Value: {shapiro_p:.4f}")
if shapiro_p < 0.05:
    print("The residuals are not normally distributed (reject H0).")
else:
    print("The residuals are normally distributed (fail to reject H0).")

#p1 Question 8 Homogeneity of Variance
print("Question 8: Homogeneity of Variance")
#Standardize residuals

standardized_residuals = dstm_mod.get_influence().resid_studentized_internal

fitted_values = dstm_mod.fittedvalues

#Create plot

plt.figure(figsize=(8,6))
sns.scatterplot(x=fitted_values, y=standardized_residuals)
plt.axhline(0, color='red', linestyle='--')
plt.axhline(3, color='blue', linestyle='--')
plt.axhline(-3, color='blue', linestyle='--')
plt.title("Standardized Residuals vs. Fitted Values", fontsize=16)
plt.xlabel("Fitted Values")
plt.ylabel("Standardized Residuals")
plt.show()

#B-P test

bp_test = het_breuschpagan(dstm_mod.resid, dstm_mod.model.exog)

#F-stat

bp_stat = bp_test[0]

#p-value

bp_p = bp_test[1]

print(f"F-statistic: {bp_stat}")
print(f"F p-value: {bp_p}")
if bp_p < 0.05:
    print("Heteroscedasticity detected (reject H0). Constant Variance not assumed.")
else:
    print("No heteroscedasticity detected (fail to reject H0). Constant Variance assumed.")


#p1 Question 9
print("Question 9")
#Print Anova Table

print(dstm_table.loc[["Teaching_Method", "Prior_Knowledge"]])

#p1 Question 10 Tukey HSD
print("Question 10: Tukey's HSD")
tukey_result = pairwise_tukeyhsd(endog=dstm['Score'], groups=dstm['Teaching_Method'],
                                 alpha=0.05)

#Tukey Visualization

tukey_result.plot_simultaneous()
plt.show()

print(tukey_result)
# Out:
# Question 6: Exploratory Data Analysis
# ['Prior_Knowledge', 'Teaching_Method', 'Score']
#                 count unique     top freq       mean       std    min     25%  \
# Prior_Knowledge    60      2     Low   30        NaN       NaN    NaN     NaN
# Teaching_Method    60      3  Direct   20        NaN       NaN    NaN     NaN
# Score            60.0    NaN     NaN  NaN  82.235333  8.142707  62.49  75.495
#
#                     50%      75%     max
# Prior_Knowledge     NaN      NaN     NaN
# Teaching_Method     NaN      NaN     NaN
# Score            82.355  88.6425  101.29
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Prior_Knowledge  60 non-null     object
#  1   Teaching_Method  60 non-null     object
#  2   Score            60 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ KB
# None
# ...

# %%
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
from statsmodels.stats.diagnostic import het_breuschpagan

##Part 2

#p2 Import Data#
ole = pd.read_excel("Online Learning and Engagement.xlsx", engine = 'openpyxl')

#p2 Question 6 Exploratory Data Analysis.
print("Question 6: Exploratory Data Analysis")
print(ole.columns.tolist())
print(ole.describe(include="all").T)

ole_stats = ole.groupby("Platform")["Engagement"].agg(['mean','std'])

print(ole_stats)

#Build Boxplot
sns.set_style("whitegrid")
sns.boxplot(
    data=ole,
    x='Platform',
    y='Engagement'
)
plt.title("Engagement of Students from Different learning platforms\nStudent Engagement Test",
          loc='center',
          fontsize=16)
plt.show()

#p2 Question 7 ANOVA
print("Question 7")
ole_mod = ols('Engagement ~ Platform+Day+Section', data=ole).fit()
print(ole_mod.summary())
#Residuals
residuals = ole_mod.resid

#QQ plot
sm.qqplot(residuals, line='s')
plt.title("QQ Plot of Residuals")
plt.show()

#S-W test
shapiro = stats.shapiro(residuals)
print(shapiro)

#Test stat and p-value
sw_stat = shapiro.statistic
sw_pval = shapiro.pvalue
print(f"Shapiro-Wilk Test Statistic: {sw_stat:.4f}, p-value: {sw_pval:.4f}")
if sw_pval > 0.05:
    print("✅ Residuals appear to be normally distributed (fail to reject H0).")
else:
    print("❌ Residuals do not appear to be normally distributed (reject H0).")

#p2 Question 8 Homogeneity of Variance
print("Question 8: Homogeneity of Variance")
standardized_residuals = ole_mod.get_influence().resid_studentized_internal

#Get the fitted values

fitted_values = ole_mod.fittedvalues

#Create the plot

plt.figure(figsize=(8, 6))
sns.scatterplot(x=fitted_values, y=standardized_residuals)
plt.axhline(y=0, linestyle='dashed', color='red')
plt.axhline(y=3, color='blue')
plt.axhline(y=-3, color='blue')
plt.xlabel("Predicted y's")
plt.ylabel("Standardized Residuals")
plt.title("Standardized Residuals vs. Fitted Values")
plt.style.use('classic')
plt.show()

#B-P Test

bp_test = het_breuschpagan(ole_mod.resid,ole_mod.model.exog)

#Extract F-statistic and p-value

f_statistic = bp_test[2]
f_p_value = bp_test[3]

print(f"F-statistic: {f_statistic}")
print(f"F p-value: {f_p_value}")
if f_p_value > 0.05:
    print("✅ Residuals appear to have constant variance (fail to reject H0).")
else:
    print("❌ Residuals do not appear to have constant variance (reject H0).")

#p2 Question 9
print("Question 9")
#Print ANOVA Table
ole_tab = sm.stats.anova_lm(ole_mod,typ=3)
#add Significance Column
ole_tab['Sig'] = np.where(ole_tab['PR(>F)']<0.05,'Yes','No')
#print only the main effect and blocking factor row
print(ole_tab.loc[['Platform','Section','Day']])

#p2 Question 10
print("Question 10: Tukey's HSD")
tukey_result = pairwise_tukeyhsd(endog=ole['Engagement'], groups=ole['Platform'], alpha=0.05)

tukey_result.plot_simultaneous()
plt.show()

print(tukey_result)
# Out:
# Question 6: Exploratory Data Analysis
# ['Day', 'Section', 'Platform', 'Engagement']
#            count unique      top freq         mean        std      min  \
# Day           16      4   Monday    4          NaN        NaN      NaN
# Section       16      4  Morning    4          NaN        NaN      NaN
# Platform      16      4        A    4          NaN        NaN      NaN
# Engagement  16.0    NaN      NaN  NaN  1365.058125  40.326882  1290.89
#
#                   25%       50%       75%      max
# Day               NaN       NaN       NaN      NaN
# Section           NaN       NaN       NaN      NaN
# Platform          NaN       NaN       NaN      NaN
# Engagement  1339.2475  1374.125  1389.285  1436.86
#                mean        std
# Platform
# A         1408.8475  19.319733
# B         1339.7200  39.845434
# C         1332.6425  32.288451
# D         1379.0225   7.354601
# Question 7
#                             OLS Regression Results
# ...
